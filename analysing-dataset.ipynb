# %% [markdown]
# # Analysing the dataset

# %% [markdown]
# **Import library's**

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Load dataset & get only values**

# %%
dataset = pd.read_csv("pollution.csv", header=0, index_col=0)

values = dataset.values

# %% [markdown]
# **Create display_dataset function**

# %%
def display_dataset(dataset, values):
    groups = [0, 1, 2, 3, 5, 6, 7]
    i = 1
    
    plt.figure(figsize=(15, 15))
    
    for group in groups:
        
        plt.subplot(len(groups), 1, i)
        plt.plot(values[:, group])
        plt.title(dataset.columns[group], y=0.5, pad=10.5, loc='left')
        i += 1
    plt.show()

# %%
display_dataset(dataset, values)
